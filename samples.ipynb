# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook
from datetime import time

# %%
df = pd.read_csv('datasets/90460.csv', dtype=str)
df.columns
# Out:
# Index(['Sample ID', 'SAMPLESTATUS', 'Dataset Status', 'DATASET', 'PARAMLISTID',
#        'PARAMID', 'DISPLAYVALUE', 'RELEASEDFLAG',
#        'sdidataapproval.approvalflag', 'sdidata.approvalflag', 'Collect Date',
#        'U_CONDITION', 'Type', 'Department', 'Room', 'SP Code', 'Person', 'TM',
#        'WORKITEMID', 'SPECID', 'Normal', 'Alert', 'Action', 'Incident Type',
#        'Incident Value', 'U_ACTIONLIMITEXCEEDED', 'U_SINGLESAMPLEALERTEXE',
#        'CONDITION', 'U_3X', 'U_3XEVALUTED', 'COLLECTEDBY', 'U_BATCHNO'],
#       dtype='object')

# %%
df['collectdt'] = pd.to_datetime(df['Collect Date'], format = '%Y-%m-%d %H:%M:%S')

# %%
df.head()
cfu = df[(df['PARAMID']=='CFU') & (df['SAMPLESTATUS']=='Approved')]
cfu[['DISPLAYVALUE']] = cfu[['DISPLAYVALUE']].astype(float)
x = cfu[cfu['DISPLAYVALUE'] > 0]
x
# Out:
#    Sample ID SAMPLESTATUS Dataset Status DATASET     PARAMLISTID  \
# 0  020791786    Completed       Released       1       PCAverage
# 1  020791786    Completed       Released       1       PCAverage
# 2  020791786    Completed       Released       1  Particle Count
# 3  020791786    Completed       Released       1  Particle Count
# 4  020791786    Completed       Released       1  Particle Count
#
#                 PARAMID DISPLAYVALUE RELEASEDFLAG  \
# 0  Average of Cal >=5.0            1            Y
# 1  Average of Cal >=0.5           64            Y
# 2             Cal >=5.0      0.99997            Y
# 3              >= 5.0 u            1            Y
# 4                  Unit           CM            Y
#
#   sdidataapproval.approvalflag sdidata.approvalflag  ... Incident Type  \
# 0                            U                  NaN  ...           NaN
# 1                            U                  NaN  ...           NaN
# ...

# %%
onesp = cfu[cfu['SP Code'] == '71-114-D-AS.1']
img = onesp.reindex(columns=['DISPLAYVALUE', 'collectdt']).sort_values('collectdt')
img.set_index('collectdt', inplace=True)
img
# Out:
#                      DISPLAYVALUE
# collectdt
# 2019-08-16 03:39:00           1.0
# 2019-08-20 12:08:00          94.0
# 2019-08-21 08:01:00           2.0
# 2019-08-28 04:47:00           0.0
# 2019-08-30 05:00:00           0.0
# 2019-09-04 03:53:00           5.0
# 2019-09-06 04:23:00           0.0

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax1.plot(img, 'ko--')
# Out:
# <img src="data:image/png;base64,..." width="640">
